# %% [markdown]
# # Training model in Google Cloud

# %% [markdown]
# The container where this notebook is running has installed Google Cloud SDK.
# To train model in cluster in Google Cloud you must log in. To do this, execute the following command from the console
#
# ```
# docker exec -it <container name> gcloud init
# ```

# %% [markdown]
# ## Config variables

# %% [markdown]
# Name of the bucket in Cloud Storage where we save the files

# %%
GCS_BUCKET='es_kiff'

# %% [markdown]
# Config file name

# %%
#CONFIG_FILE = 'rfcn_resnet101GCP.config'
#CONFIG_FILE = 'ssd_mobilenetGCP.config'
CONFIG_FILE = 'faster_rcnn_inception_resnetGCP.config'

# %% [markdown]
# Pretraining model name

# %%
#PRETRAINING_MODEL = 'faster_rcnn_resnet101_coco_11_06_2017'
#PRETRAINING_MODEL = 'ssd_mobilenet_v1_coco_2018_01_28'
PRETRAINING_MODEL = 'faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28'

# %% [markdown]
# Path to train, test and labels files

# %%
trainRecordPath = '/u01/notebooks/TFM/DatasetCreator/out/train.record'
testRecordPath = '/u01/notebooks/TFM/DatasetCreator/out/test.record'
labelsPath = '/u01/notebooks/TFM/DatasetCreator/out/label_map.pbtxt'

# %% [markdown]
# ## Data and configuration preparation

# %% [markdown]
# Upload files to Cloud Storage

# %%
# !gsutil cp $trainRecordPath gs://$GCS_BUCKET/data/
# !gsutil cp $testRecordPath gs://$GCS_BUCKET/data/
# !gsutil cp $labelsPath gs://$GCS_BUCKET/data/label_map.pbtxt
# Out:
# Copying file:///u01/notebooks/TFM/DatasetCreator/out/train.record [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# - [1 files][246.7 MiB/246.7 MiB]    4.3 MiB/s
# Operation completed over 1 objects/246.7 MiB.
# Copying file:///u01/notebooks/TFM/DatasetCreator/out/test.record [Content-Type=application/octet-stream]...
# | [1 files][ 23.9 MiB/ 23.9 MiB]
# Operation completed over 1 objects/23.9 MiB.
# Copying file:///u01/notebooks/TFM/DatasetCreator/out/label_map.pbtxt [Content-Type=application/octet-stream]...
# / [1 files][  499.0 B/  499.0 B]
# Operation completed over 1 objects/499.0 B.

# %% [markdown]
# Get pretraining model and upload to Cloud Storage

# %%
#!wget http://storage.googleapis.com/download.tensorflow.org/models/object_detection/faster_rcnn_resnet101_coco_11_06_2017.tar.gz
#!tar -xvf faster_rcnn_resnet101_coco_11_06_2017.tar.gz
#!gsutil cp faster_rcnn_resnet101_coco_11_06_2017/model.ckpt.* gs://$GCS_BUCKET/data/
      
# !wget http://download.tensorflow.org/models/object_detection/{PRETRAINING_MODEL}.tar.gz
# !tar -xvf {PRETRAINING_MODEL}.tar.gz
# !gsutil cp {PRETRAINING_MODEL}/model.ckpt.* gs://$GCS_BUCKET/data/
# Out:
# --2019-05-25 21:18:52--  http://download.tensorflow.org/models/object_detection/faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 172.217.168.176, 2a00:1450:4003:80a::2010
# Connecting to download.tensorflow.org (download.tensorflow.org)|172.217.168.176|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 672221478 (641M) [application/x-tar]
# Saving to: ‘faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28.tar.gz’
#
# faster_rcnn_incepti 100%[===================>] 641.08M  22.4MB/s    in 34s
#
# 2019-05-25 21:19:27 (18.6 MB/s) - ‘faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28.tar.gz’ saved [672221478/672221478]
#
# faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/
# faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.index
# faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/checkpoint
# faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/pipeline.config
# faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.data-00000-of-00001
# faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.meta
# faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/saved_model/
# faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/saved_model/saved_model.pb
# faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/saved_model/variables/
# faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/frozen_inference_graph.pb
# Copying file://faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.data-00000-of-00001 [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Copying file://faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.index [Content-Type=application/octet-stream]...
# Copying file://faster_rcnn_inception_resnet_v2_atrous_coco_2018_01_28/model.ckpt.meta [Content-Type=application/octet-stream]...
# - [3 files][239.7 MiB/239.7 MiB]    2.5 MiB/s
# Operation completed over 3 objects/239.7 MiB.

# %% [markdown]
# Replace paths in config file and upload to Cloud Storage

# %%
# !sed -i "s|PATH_TO_BE_CONFIGURED|"gs://$GCS_BUCKET"/data|g"  /u01/notebooks/TFM/Configs/$CONFIG_FILE
# !gsutil cp /u01/notebooks/TFM/Configs/$CONFIG_FILE gs://$GCS_BUCKET/data/$CONFIG_FILE
# Out:
# Copying file:///u01/notebooks/TFM/Configs/faster_rcnn_inception_resnetGCP.config [Content-Type=application/octet-stream]...
# - [1 files][  3.1 KiB/  3.1 KiB]
# Operation completed over 1 objects/3.1 KiB.

# %% [markdown]
# Change to tesorflow research folder

# %%
cd /u01/notebooks/models/research/
# Out:
# /u01/notebooks/models/research

# %% [markdown]
# Packaging to run in Cloud ML

# %%
# !bash object_detection/dataset_tools/create_pycocotools_package.sh /tmp/pycocotools
# !python setup.py sdist
!(cd slim && python setup.py sdist)
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 953, done.
# remote: Total 953 (delta 0), reused 0 (delta 0), pack-reused 953
# Receiving objects: 100% (953/953), 11.70 MiB | 11.13 MiB/s, done.
# Resolving deltas: 100% (565/565), done.
# running sdist
# running egg_info
# writing object_detection.egg-info/PKG-INFO
# writing dependency_links to object_detection.egg-info/dependency_links.txt
# writing requirements to object_detection.egg-info/requires.txt
# writing top-level names to object_detection.egg-info/top_level.txt
# reading manifest file 'object_detection.egg-info/SOURCES.txt'
# writing manifest file 'object_detection.egg-info/SOURCES.txt'
# running check
# warning: check: missing required meta-data: url
#
# warning: check: missing meta-data: either (author and author_email) or (maintainer and maintainer_email) must be supplied
#
# creating object_detection-0.1
# creating object_detection-0.1/object_detection
# creating object_detection-0.1/object_detection.egg-info
# creating object_detection-0.1/object_detection/anchor_generators
# creating object_detection-0.1/object_detection/box_coders
# creating object_detection-0.1/object_detection/builders
# creating object_detection-0.1/object_detection/core
# creating object_detection-0.1/object_detection/data_decoders
# creating object_detection-0.1/object_detection/dataset_tools
# creating object_detection-0.1/object_detection/inference
# creating object_detection-0.1/object_detection/legacy
# creating object_detection-0.1/object_detection/matchers
# creating object_detection-0.1/object_detection/meta_architectures
# creating object_detection-0.1/object_detection/metrics
# creating object_detection-0.1/object_detection/models
# creating object_detection-0.1/object_detection/models/keras_models
# creating object_detection-0.1/object_detection/predictors
# creating object_detection-0.1/object_detection/predictors/heads
# creating object_detection-0.1/object_detection/protos
# creating object_detection-0.1/object_detection/utils
# copying files to object_detection-0.1...
# copying README.md -> object_detection-0.1
# copying setup.py -> object_detection-0.1
# copying object_detection/__init__.py -> object_detection-0.1/object_detection
# copying object_detection/eval_util.py -> object_detection-0.1/object_detection
# copying object_detection/eval_util_test.py -> object_detection-0.1/object_detection
# copying object_detection/export_inference_graph.py -> object_detection-0.1/object_detection
# copying object_detection/export_tflite_ssd_graph.py -> object_detection-0.1/object_detection
# copying object_detection/export_tflite_ssd_graph_lib.py -> object_detection-0.1/object_detection
# copying object_detection/export_tflite_ssd_graph_lib_test.py -> object_detection-0.1/object_detection
# copying object_detection/exporter.py -> object_detection-0.1/object_detection
# copying object_detection/exporter_test.py -> object_detection-0.1/object_detection
# copying object_detection/inputs.py -> object_detection-0.1/object_detection
# copying object_detection/inputs_test.py -> object_detection-0.1/object_detection
# copying object_detection/model_hparams.py -> object_detection-0.1/object_detection
# copying object_detection/model_lib.py -> object_detection-0.1/object_detection
# copying object_detection/model_lib_test.py -> object_detection-0.1/object_detection
# copying object_detection/model_main.py -> object_detection-0.1/object_detection
# copying object_detection/model_tpu_main.py -> object_detection-0.1/object_detection
# copying object_detection.egg-info/PKG-INFO -> object_detection-0.1/object_detection.egg-info
# copying object_detection.egg-info/SOURCES.txt -> object_detection-0.1/object_detection.egg-info
# copying object_detection.egg-info/dependency_links.txt -> object_detection-0.1/object_detection.egg-info
# copying object_detection.egg-info/requires.txt -> object_detection-0.1/object_detection.egg-info
# copying object_detection.egg-info/top_level.txt -> object_detection-0.1/object_detection.egg-info
# copying object_detection/anchor_generators/__init__.py -> object_detection-0.1/object_detection/anchor_generators
# copying object_detection/anchor_generators/grid_anchor_generator.py -> object_detection-0.1/object_detection/anchor_generators
# copying object_detection/anchor_generators/grid_anchor_generator_test.py -> object_detection-0.1/object_detection/anchor_generators
# copying object_detection/anchor_generators/multiple_grid_anchor_generator.py -> object_detection-0.1/object_detection/anchor_generators
# copying object_detection/anchor_generators/multiple_grid_anchor_generator_test.py -> object_detection-0.1/object_detection/anchor_generators
# copying object_detection/anchor_generators/multiscale_grid_anchor_generator.py -> object_detection-0.1/object_detection/anchor_generators
# copying object_detection/anchor_generators/multiscale_grid_anchor_generator_test.py -> object_detection-0.1/object_detection/anchor_generators
# copying object_detection/box_coders/__init__.py -> object_detection-0.1/object_detection/box_coders
# copying object_detection/box_coders/faster_rcnn_box_coder.py -> object_detection-0.1/object_detection/box_coders
# copying object_detection/box_coders/faster_rcnn_box_coder_test.py -> object_detection-0.1/object_detection/box_coders
# copying object_detection/box_coders/keypoint_box_coder.py -> object_detection-0.1/object_detection/box_coders
# copying object_detection/box_coders/keypoint_box_coder_test.py -> object_detection-0.1/object_detection/box_coders
# copying object_detection/box_coders/mean_stddev_box_coder.py -> object_detection-0.1/object_detection/box_coders
# copying object_detection/box_coders/mean_stddev_box_coder_test.py -> object_detection-0.1/object_detection/box_coders
# copying object_detection/box_coders/square_box_coder.py -> object_detection-0.1/object_detection/box_coders
# copying object_detection/box_coders/square_box_coder_test.py -> object_detection-0.1/object_detection/box_coders
# copying object_detection/builders/__init__.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/anchor_generator_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/anchor_generator_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/box_coder_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/box_coder_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/box_predictor_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/box_predictor_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/calibration_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/calibration_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/dataset_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/dataset_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/graph_rewriter_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/graph_rewriter_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/hyperparams_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/hyperparams_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/image_resizer_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/image_resizer_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/input_reader_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/input_reader_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/losses_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/losses_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/matcher_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/matcher_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/model_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/model_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/optimizer_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/optimizer_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/post_processing_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/post_processing_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/preprocessor_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/preprocessor_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/region_similarity_calculator_builder.py -> object_detection-0.1/object_detection/builders
# copying object_detection/builders/region_similarity_calculator_builder_test.py -> object_detection-0.1/object_detection/builders
# copying object_detection/core/__init__.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/anchor_generator.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/balanced_positive_negative_sampler.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/balanced_positive_negative_sampler_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/batcher.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/batcher_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/box_coder.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/box_coder_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/box_list.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/box_list_ops.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/box_list_ops_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/box_list_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/box_predictor.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/data_decoder.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/data_parser.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/freezable_batch_norm.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/freezable_batch_norm_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/keypoint_ops.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/keypoint_ops_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/losses.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/losses_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/matcher.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/matcher_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/minibatch_sampler.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/minibatch_sampler_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/model.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/post_processing.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/post_processing_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/prefetcher.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/prefetcher_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/preprocessor.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/preprocessor_cache.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/preprocessor_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/region_similarity_calculator.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/region_similarity_calculator_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/standard_fields.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/target_assigner.py -> object_detection-0.1/object_detection/core
# copying object_detection/core/target_assigner_test.py -> object_detection-0.1/object_detection/core
# copying object_detection/data_decoders/__init__.py -> object_detection-0.1/object_detection/data_decoders
# copying object_detection/data_decoders/tf_example_decoder.py -> object_detection-0.1/object_detection/data_decoders
# copying object_detection/data_decoders/tf_example_decoder_test.py -> object_detection-0.1/object_detection/data_decoders
# copying object_detection/dataset_tools/__init__.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/create_coco_tf_record.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/create_coco_tf_record_test.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/create_kitti_tf_record.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/create_kitti_tf_record_test.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/create_oid_tf_record.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/create_pascal_tf_record.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/create_pascal_tf_record_test.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/create_pet_tf_record.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/oid_hierarchical_labels_expansion.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/oid_hierarchical_labels_expansion_test.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/oid_tfrecord_creation.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/oid_tfrecord_creation_test.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/tf_record_creation_util.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/dataset_tools/tf_record_creation_util_test.py -> object_detection-0.1/object_detection/dataset_tools
# copying object_detection/inference/__init__.py -> object_detection-0.1/object_detection/inference
# copying object_detection/inference/detection_inference.py -> object_detection-0.1/object_detection/inference
# copying object_detection/inference/detection_inference_test.py -> object_detection-0.1/object_detection/inference
# copying object_detection/inference/infer_detections.py -> object_detection-0.1/object_detection/inference
# copying object_detection/legacy/__init__.py -> object_detection-0.1/object_detection/legacy
# copying object_detection/legacy/eval.py -> object_detection-0.1/object_detection/legacy
# copying object_detection/legacy/evaluator.py -> object_detection-0.1/object_detection/legacy
# copying object_detection/legacy/train.py -> object_detection-0.1/object_detection/legacy
# copying object_detection/legacy/trainer.py -> object_detection-0.1/object_detection/legacy
# copying object_detection/legacy/trainer_test.py -> object_detection-0.1/object_detection/legacy
# copying object_detection/matchers/__init__.py -> object_detection-0.1/object_detection/matchers
# copying object_detection/matchers/argmax_matcher.py -> object_detection-0.1/object_detection/matchers
# copying object_detection/matchers/argmax_matcher_test.py -> object_detection-0.1/object_detection/matchers
# copying object_detection/matchers/bipartite_matcher.py -> object_detection-0.1/object_detection/matchers
# copying object_detection/matchers/bipartite_matcher_test.py -> object_detection-0.1/object_detection/matchers
# copying object_detection/meta_architectures/__init__.py -> object_detection-0.1/object_detection/meta_architectures
# copying object_detection/meta_architectures/faster_rcnn_meta_arch.py -> object_detection-0.1/object_detection/meta_architectures
# copying object_detection/meta_architectures/faster_rcnn_meta_arch_test.py -> object_detection-0.1/object_detection/meta_architectures
# copying object_detection/meta_architectures/faster_rcnn_meta_arch_test_lib.py -> object_detection-0.1/object_detection/meta_architectures
# copying object_detection/meta_architectures/rfcn_meta_arch.py -> object_detection-0.1/object_detection/meta_architectures
# copying object_detection/meta_architectures/rfcn_meta_arch_test.py -> object_detection-0.1/object_detection/meta_architectures
# copying object_detection/meta_architectures/ssd_meta_arch.py -> object_detection-0.1/object_detection/meta_architectures
# copying object_detection/meta_architectures/ssd_meta_arch_test.py -> object_detection-0.1/object_detection/meta_architectures
# copying object_detection/meta_architectures/ssd_meta_arch_test_lib.py -> object_detection-0.1/object_detection/meta_architectures
# copying object_detection/metrics/__init__.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/calibration_evaluation.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/calibration_evaluation_test.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/calibration_metrics.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/calibration_metrics_test.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/coco_evaluation.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/coco_evaluation_test.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/coco_tools.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/coco_tools_test.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/io_utils.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/offline_eval_map_corloc.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/offline_eval_map_corloc_test.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/oid_od_challenge_evaluation.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/oid_od_challenge_evaluation_utils.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/oid_od_challenge_evaluation_utils_test.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/oid_vrd_challenge_evaluation.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/oid_vrd_challenge_evaluation_utils.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/oid_vrd_challenge_evaluation_utils_test.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/tf_example_parser.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/metrics/tf_example_parser_test.py -> object_detection-0.1/object_detection/metrics
# copying object_detection/models/__init__.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/embedded_ssd_mobilenet_v1_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/embedded_ssd_mobilenet_v1_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_inception_resnet_v2_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_inception_resnet_v2_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_inception_v2_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_inception_v2_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_mobilenet_v1_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_mobilenet_v1_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_nas_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_nas_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_pnas_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_pnas_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_resnet_v1_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/faster_rcnn_resnet_v1_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/feature_map_generators.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/feature_map_generators_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_inception_v2_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_inception_v2_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_inception_v3_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_inception_v3_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v1_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v1_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v1_fpn_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v1_fpn_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v1_keras_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v1_ppn_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v1_ppn_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v2_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v2_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v2_fpn_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v2_fpn_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_mobilenet_v2_keras_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_pnasnet_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_pnasnet_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_resnet_v1_fpn_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_resnet_v1_fpn_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_resnet_v1_fpn_feature_extractor_testbase.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_resnet_v1_ppn_feature_extractor.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_resnet_v1_ppn_feature_extractor_test.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/ssd_resnet_v1_ppn_feature_extractor_testbase.py -> object_detection-0.1/object_detection/models
# copying object_detection/models/keras_models/__init__.py -> object_detection-0.1/object_detection/models/keras_models
# copying object_detection/models/keras_models/mobilenet_v1.py -> object_detection-0.1/object_detection/models/keras_models
# copying object_detection/models/keras_models/mobilenet_v1_test.py -> object_detection-0.1/object_detection/models/keras_models
# copying object_detection/models/keras_models/mobilenet_v2.py -> object_detection-0.1/object_detection/models/keras_models
# copying object_detection/models/keras_models/mobilenet_v2_test.py -> object_detection-0.1/object_detection/models/keras_models
# copying object_detection/models/keras_models/original_mobilenet_v2.py -> object_detection-0.1/object_detection/models/keras_models
# copying object_detection/models/keras_models/test_utils.py -> object_detection-0.1/object_detection/models/keras_models
# copying object_detection/predictors/__init__.py -> object_detection-0.1/object_detection/predictors
# copying object_detection/predictors/convolutional_box_predictor.py -> object_detection-0.1/object_detection/predictors
# copying object_detection/predictors/convolutional_box_predictor_test.py -> object_detection-0.1/object_detection/predictors
# copying object_detection/predictors/convolutional_keras_box_predictor.py -> object_detection-0.1/object_detection/predictors
# copying object_detection/predictors/convolutional_keras_box_predictor_test.py -> object_detection-0.1/object_detection/predictors
# copying object_detection/predictors/mask_rcnn_box_predictor.py -> object_detection-0.1/object_detection/predictors
# copying object_detection/predictors/mask_rcnn_box_predictor_test.py -> object_detection-0.1/object_detection/predictors
# copying object_detection/predictors/rfcn_box_predictor.py -> object_detection-0.1/object_detection/predictors
# copying object_detection/predictors/rfcn_box_predictor_test.py -> object_detection-0.1/object_detection/predictors
# copying object_detection/predictors/heads/__init__.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/box_head.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/box_head_test.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/class_head.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/class_head_test.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/head.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/keras_box_head.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/keras_box_head_test.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/keras_class_head.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/keras_class_head_test.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/keras_mask_head.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/keras_mask_head_test.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/keypoint_head.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/keypoint_head_test.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/mask_head.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/predictors/heads/mask_head_test.py -> object_detection-0.1/object_detection/predictors/heads
# copying object_detection/protos/__init__.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/anchor_generator_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/argmax_matcher_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/bipartite_matcher_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/box_coder_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/box_predictor_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/calibration_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/eval_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/faster_rcnn_box_coder_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/faster_rcnn_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/graph_rewriter_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/grid_anchor_generator_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/hyperparams_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/image_resizer_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/input_reader_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/keypoint_box_coder_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/losses_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/matcher_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/mean_stddev_box_coder_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/model_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/multiscale_anchor_generator_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/optimizer_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/pipeline_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/post_processing_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/preprocessor_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/region_similarity_calculator_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/square_box_coder_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/ssd_anchor_generator_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/ssd_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/string_int_label_map_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/protos/train_pb2.py -> object_detection-0.1/object_detection/protos
# copying object_detection/utils/__init__.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/category_util.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/category_util_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/config_util.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/config_util_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/context_manager.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/context_manager_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/dataset_util.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/dataset_util_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/json_utils.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/json_utils_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/label_map_util.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/label_map_util_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/learning_schedules.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/learning_schedules_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/metrics.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/metrics_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_box_list.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_box_list_ops.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_box_list_ops_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_box_list_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_box_mask_list.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_box_mask_list_ops.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_box_mask_list_ops_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_box_mask_list_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_box_ops.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_box_ops_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_mask_ops.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/np_mask_ops_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/object_detection_evaluation.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/object_detection_evaluation_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/ops.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/ops_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/per_image_evaluation.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/per_image_evaluation_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/per_image_vrd_evaluation.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/per_image_vrd_evaluation_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/shape_utils.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/shape_utils_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/static_shape.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/static_shape_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/test_case.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/test_utils.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/test_utils_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/variables_helper.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/variables_helper_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/visualization_utils.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/visualization_utils_test.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/vrd_evaluation.py -> object_detection-0.1/object_detection/utils
# copying object_detection/utils/vrd_evaluation_test.py -> object_detection-0.1/object_detection/utils
# Writing object_detection-0.1/setup.cfg
# Creating tar archive
# removing 'object_detection-0.1' (and everything under it)
# running sdist
# running egg_info
# writing slim.egg-info/PKG-INFO
# writing dependency_links to slim.egg-info/dependency_links.txt
# writing top-level names to slim.egg-info/top_level.txt
# reading manifest file 'slim.egg-info/SOURCES.txt'
# writing manifest file 'slim.egg-info/SOURCES.txt'
# running check
# warning: check: missing required meta-data: url
#
# warning: check: missing meta-data: either (author and author_email) or (maintainer and maintainer_email) must be supplied
#
# creating slim-0.1
# creating slim-0.1/datasets
# creating slim-0.1/deployment
# creating slim-0.1/nets
# creating slim-0.1/nets/mobilenet
# creating slim-0.1/nets/nasnet
# creating slim-0.1/preprocessing
# creating slim-0.1/slim.egg-info
# copying files to slim-0.1...
# copying README.md -> slim-0.1
# copying setup.py -> slim-0.1
# copying datasets/__init__.py -> slim-0.1/datasets
# copying datasets/build_imagenet_data.py -> slim-0.1/datasets
# copying datasets/build_visualwakewords_data.py -> slim-0.1/datasets
# copying datasets/build_visualwakewords_data_lib.py -> slim-0.1/datasets
# copying datasets/cifar10.py -> slim-0.1/datasets
# copying datasets/dataset_factory.py -> slim-0.1/datasets
# copying datasets/dataset_utils.py -> slim-0.1/datasets
# copying datasets/download_and_convert_cifar10.py -> slim-0.1/datasets
# copying datasets/download_and_convert_flowers.py -> slim-0.1/datasets
# copying datasets/download_and_convert_mnist.py -> slim-0.1/datasets
# copying datasets/flowers.py -> slim-0.1/datasets
# copying datasets/imagenet.py -> slim-0.1/datasets
# copying datasets/mnist.py -> slim-0.1/datasets
# copying datasets/preprocess_imagenet_validation_data.py -> slim-0.1/datasets
# copying datasets/process_bounding_boxes.py -> slim-0.1/datasets
# copying datasets/visualwakewords.py -> slim-0.1/datasets
# copying deployment/__init__.py -> slim-0.1/deployment
# copying deployment/model_deploy.py -> slim-0.1/deployment
# copying deployment/model_deploy_test.py -> slim-0.1/deployment
# copying nets/__init__.py -> slim-0.1/nets
# copying nets/alexnet.py -> slim-0.1/nets
# copying nets/alexnet_test.py -> slim-0.1/nets
# copying nets/cifarnet.py -> slim-0.1/nets
# copying nets/cyclegan.py -> slim-0.1/nets
# copying nets/cyclegan_test.py -> slim-0.1/nets
# copying nets/dcgan.py -> slim-0.1/nets
# copying nets/dcgan_test.py -> slim-0.1/nets
# copying nets/i3d.py -> slim-0.1/nets
# copying nets/i3d_test.py -> slim-0.1/nets
# copying nets/i3d_utils.py -> slim-0.1/nets
# copying nets/inception.py -> slim-0.1/nets
# copying nets/inception_resnet_v2.py -> slim-0.1/nets
# copying nets/inception_resnet_v2_test.py -> slim-0.1/nets
# copying nets/inception_utils.py -> slim-0.1/nets
# copying nets/inception_v1.py -> slim-0.1/nets
# copying nets/inception_v1_test.py -> slim-0.1/nets
# copying nets/inception_v2.py -> slim-0.1/nets
# copying nets/inception_v2_test.py -> slim-0.1/nets
# copying nets/inception_v3.py -> slim-0.1/nets
# copying nets/inception_v3_test.py -> slim-0.1/nets
# copying nets/inception_v4.py -> slim-0.1/nets
# copying nets/inception_v4_test.py -> slim-0.1/nets
# copying nets/lenet.py -> slim-0.1/nets
# copying nets/mobilenet_v1.py -> slim-0.1/nets
# copying nets/mobilenet_v1_eval.py -> slim-0.1/nets
# copying nets/mobilenet_v1_test.py -> slim-0.1/nets
# copying nets/mobilenet_v1_train.py -> slim-0.1/nets
# copying nets/nets_factory.py -> slim-0.1/nets
# copying nets/nets_factory_test.py -> slim-0.1/nets
# copying nets/overfeat.py -> slim-0.1/nets
# copying nets/overfeat_test.py -> slim-0.1/nets
# copying nets/pix2pix.py -> slim-0.1/nets
# copying nets/pix2pix_test.py -> slim-0.1/nets
# copying nets/resnet_utils.py -> slim-0.1/nets
# copying nets/resnet_v1.py -> slim-0.1/nets
# copying nets/resnet_v1_test.py -> slim-0.1/nets
# copying nets/resnet_v2.py -> slim-0.1/nets
# copying nets/resnet_v2_test.py -> slim-0.1/nets
# copying nets/s3dg.py -> slim-0.1/nets
# copying nets/s3dg_test.py -> slim-0.1/nets
# copying nets/vgg.py -> slim-0.1/nets
# copying nets/vgg_test.py -> slim-0.1/nets
# copying nets/mobilenet/__init__.py -> slim-0.1/nets/mobilenet
# copying nets/mobilenet/conv_blocks.py -> slim-0.1/nets/mobilenet
# copying nets/mobilenet/mobilenet.py -> slim-0.1/nets/mobilenet
# copying nets/mobilenet/mobilenet_v2.py -> slim-0.1/nets/mobilenet
# copying nets/mobilenet/mobilenet_v2_test.py -> slim-0.1/nets/mobilenet
# copying nets/nasnet/__init__.py -> slim-0.1/nets/nasnet
# copying nets/nasnet/nasnet.py -> slim-0.1/nets/nasnet
# copying nets/nasnet/nasnet_test.py -> slim-0.1/nets/nasnet
# copying nets/nasnet/nasnet_utils.py -> slim-0.1/nets/nasnet
# copying nets/nasnet/nasnet_utils_test.py -> slim-0.1/nets/nasnet
# copying nets/nasnet/pnasnet.py -> slim-0.1/nets/nasnet
# copying nets/nasnet/pnasnet_test.py -> slim-0.1/nets/nasnet
# copying preprocessing/__init__.py -> slim-0.1/preprocessing
# copying preprocessing/cifarnet_preprocessing.py -> slim-0.1/preprocessing
# copying preprocessing/inception_preprocessing.py -> slim-0.1/preprocessing
# copying preprocessing/lenet_preprocessing.py -> slim-0.1/preprocessing
# copying preprocessing/preprocessing_factory.py -> slim-0.1/preprocessing
# copying preprocessing/vgg_preprocessing.py -> slim-0.1/preprocessing
# copying slim.egg-info/PKG-INFO -> slim-0.1/slim.egg-info
# copying slim.egg-info/SOURCES.txt -> slim-0.1/slim.egg-info
# copying slim.egg-info/dependency_links.txt -> slim-0.1/slim.egg-info
# copying slim.egg-info/top_level.txt -> slim-0.1/slim.egg-info
# Writing slim-0.1/setup.cfg
# Creating tar archive
# removing 'slim-0.1' (and everything under it)

# %% [markdown]
# Run training and validation in Cloud ML

# %%
# !gcloud ai-platform jobs submit training `whoami`_object_detection_diagrams_`date +%m_%d_%Y_%H_%M_%S` \
    --runtime-version 1.12 \
    --job-dir=gs://$GCS_BUCKET/model_dir \
    --packages dist/object_detection-0.1.tar.gz,slim/dist/slim-0.1.tar.gz,/tmp/pycocotools/pycocotools-2.0.tar.gz \
    --module-name object_detection.model_main \
    --region us-central1 \
    --config /u01/notebooks/TFM/Configs/cloud.yml \
    -- \
    --model_dir=gs://$GCS_BUCKET/model_dir \
    --pipeline_config_path=gs://$GCS_BUCKET/data/$CONFIG_FILE
# Out:
# Job [root_object_detection_diagrams_05_25_2019_22_17_02] submitted successfully.
# Your job is still active. You may view the status of your job with the command
#
#   $ gcloud ai-platform jobs describe root_object_detection_diagrams_05_25_2019_22_17_02
#
# or continue streaming the logs with the command
#
#   $ gcloud ai-platform jobs stream-logs root_object_detection_diagrams_05_25_2019_22_17_02
# jobId: root_object_detection_diagrams_05_25_2019_22_17_02
# state: QUEUED

# %% [markdown]
# Add credentials to connect tensorboard to Cloud Storage

# %%
# !echo '' > /u01/notebooks/TFM/Configs/key.json

# %% [markdown]
# Launch tensorboard to view progress of training and eval jobs on Google Cloud
#
# gcloud auth application-default login

# %%
# !export GOOGLE_APPLICATION_CREDENTIALS="/u01/notebooks/TFM/Configs/key.json" && tensorboard --logdir=gs://es_kiff/model_dir
# Out:
# TensorBoard 1.13.1 at http://134aafc9ad33:6006 (Press CTRL+C to quit)
# 2019-05-23 03:00:42.844908: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.623136 seconds (attempt 1 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-23 03:00:43.638326: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.545661 seconds (attempt 2 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-23 03:00:44.272542: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.38535 seconds (attempt 3 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-23 03:00:44.749049: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.16322 seconds (attempt 4 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-23 03:00:45.084295: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.365805 seconds (attempt 5 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-23 03:00:45.616527: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.589867 seconds (attempt 6 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-23 03:00:46.299249: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.654762 seconds (attempt 7 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-23 03:00:47.126170: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 1.07459 seconds (attempt 8 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-23 03:00:48.267091: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 1.29797 seconds (attempt 9 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-23 03:00:49.733716: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 1.22078 seconds (attempt 10 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-23 03:00:51.022573: W tensorflow/core/platform/cloud/google_auth_provider.cc:157] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "Invalid argument: Error executing an HTTP request: HTTP response code 400 with body '{
#   "error": "invalid_grant",
#   "error_description": "Invalid JWT: Token must be a short-lived token (60 minutes) and in a reasonable timeframe. Check your iat and exp values and use a clock with skew to account for clock differences between systems."
# }'". Retrieving token from GCE failed with "Aborted: All 10 retry attempts failed. The last failure: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'".
# Exception in thread Reloader:
# Traceback (most recent call last):
#   File "/root/anaconda3/lib/python3.7/threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "/root/anaconda3/lib/python3.7/threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/application.py", line 389, in _reload
#     multiplexer.AddRunsFromDirectory(path, name)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/event_processing/plugin_event_multiplexer.py", line 183, in AddRunsFromDirectory
#     for subdir in io_wrapper.GetLogdirSubdirectories(path):
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/event_processing/io_wrapper.py", line 179, in GetLogdirSubdirectories
#     if not tf.io.gfile.exists(path):
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorflow/python/lib/io/file_io.py", line 277, in file_exists_v2
#     pywrap_tensorflow.FileExists(compat.as_bytes(path), status)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/errors_impl.py", line 528, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.PermissionDeniedError: Error executing an HTTP request: HTTP response code 401 with body '{
#  "error": {
#   "errors": [
#    {
#     "domain": "global",
#     "reason": "required",
#     "message": "Anonymous caller does not have storage.objects.get access to es_kiff/model_dir.",
#     "locationType": "header",
#     "location": "Authorization"
#    }
#   ],
#   "code": 401,
#   "message": "Anonymous caller does not have storage.objects.get access to es_kiff/model_dir."
#  }
# }
# '
# 	 when reading metadata of gs://es_kiff/model_dir
#
# E0523 03:00:53.777364 139744723560192 _internal.py:88] Error on request:
# Traceback (most recent call last):
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/serving.py", line 258, in execute
#     application_iter = app(environ, start_response)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/application.py", line 310, in __call__
#     return self.data_applications[clean_path](environ, start_response)
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/wrappers.py", line 308, in application
#     resp = f(*args[:-2] + (request,))
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/application.py", line 281, in _serve_plugins_listing
#     response[plugin.plugin_name] = plugin.is_active()
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/plugins/beholder/beholder_plugin.py", line 74, in is_active
#     return tf.io.gfile.exists(summary_filename) and\
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorflow/python/lib/io/file_io.py", line 277, in file_exists_v2
#     pywrap_tensorflow.FileExists(compat.as_bytes(path), status)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/errors_impl.py", line 528, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.PermissionDeniedError: Error executing an HTTP request: HTTP response code 401 with body '{
#  "error": {
#   "errors": [
#    {
#     "domain": "global",
#     "reason": "required",
#     "message": "Anonymous caller does not have storage.objects.get access to es_kiff/model_dir/plugins/beholder/frame.summary.",
#     "locationType": "header",
#     "location": "Authorization"
#    }
#   ],
#   "code": 401,
#   "message": "Anonymous caller does not have storage.objects.get access to es_kiff/model_dir/plugins/beholder/frame.summary."
#  }
# }
# '
# 	 when reading metadata of gs://es_kiff/model_dir/plugins/beholder/frame.summary
# E0523 03:00:54.015628 139744723560192 _internal.py:88] Error on request:
# Traceback (most recent call last):
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/serving.py", line 258, in execute
#     application_iter = app(environ, start_response)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/application.py", line 310, in __call__
#     return self.data_applications[clean_path](environ, start_response)
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/wrappers.py", line 308, in application
#     resp = f(*args[:-2] + (request,))
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/application.py", line 281, in _serve_plugins_listing
#     response[plugin.plugin_name] = plugin.is_active()
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/plugins/beholder/beholder_plugin.py", line 74, in is_active
#     return tf.io.gfile.exists(summary_filename) and\
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorflow/python/lib/io/file_io.py", line 277, in file_exists_v2
#     pywrap_tensorflow.FileExists(compat.as_bytes(path), status)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/errors_impl.py", line 528, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.PermissionDeniedError: Error executing an HTTP request: HTTP response code 401 with body '{
#  "error": {
#   "errors": [
#    {
#     "domain": "global",
#     "reason": "required",
#     "message": "Anonymous caller does not have storage.objects.get access to es_kiff/model_dir/plugins/beholder/frame.summary.",
#     "locationType": "header",
#     "location": "Authorization"
#    }
#   ],
#   "code": 401,
#   "message": "Anonymous caller does not have storage.objects.get access to es_kiff/model_dir/plugins/beholder/frame.summary."
#  }
# }
# '
# 	 when reading metadata of gs://es_kiff/model_dir/plugins/beholder/frame.summary
# E0523 03:00:54.303530 139744723560192 _internal.py:88] Error on request:
# Traceback (most recent call last):
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/serving.py", line 258, in execute
#     application_iter = app(environ, start_response)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/application.py", line 310, in __call__
#     return self.data_applications[clean_path](environ, start_response)
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/wrappers.py", line 308, in application
#     resp = f(*args[:-2] + (request,))
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/application.py", line 281, in _serve_plugins_listing
#     response[plugin.plugin_name] = plugin.is_active()
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/plugins/beholder/beholder_plugin.py", line 74, in is_active
#     return tf.io.gfile.exists(summary_filename) and\
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorflow/python/lib/io/file_io.py", line 277, in file_exists_v2
#     pywrap_tensorflow.FileExists(compat.as_bytes(path), status)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/errors_impl.py", line 528, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.PermissionDeniedError: Error executing an HTTP request: HTTP response code 401 with body '{
#  "error": {
#   "errors": [
#    {
#     "domain": "global",
#     "reason": "required",
#     "message": "Anonymous caller does not have storage.objects.get access to es_kiff/model_dir/plugins/beholder/frame.summary.",
#     "locationType": "header",
#     "location": "Authorization"
#    }
#   ],
#   "code": 401,
#   "message": "Anonymous caller does not have storage.objects.get access to es_kiff/model_dir/plugins/beholder/frame.summary."
#  }
# }
# '
# 	 when reading metadata of gs://es_kiff/model_dir/plugins/beholder/frame.summary
# E0523 03:00:54.606239 139744723560192 _internal.py:88] Error on request:
# Traceback (most recent call last):
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/serving.py", line 270, in run_wsgi
#     execute(self.server.app)
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/serving.py", line 258, in execute
#     application_iter = app(environ, start_response)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/application.py", line 310, in __call__
#     return self.data_applications[clean_path](environ, start_response)
#   File "/root/anaconda3/lib/python3.7/site-packages/werkzeug/wrappers.py", line 308, in application
#     resp = f(*args[:-2] + (request,))
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/backend/application.py", line 281, in _serve_plugins_listing
#     response[plugin.plugin_name] = plugin.is_active()
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorboard/plugins/beholder/beholder_plugin.py", line 74, in is_active
#     return tf.io.gfile.exists(summary_filename) and\
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorflow/python/lib/io/file_io.py", line 277, in file_exists_v2
#     pywrap_tensorflow.FileExists(compat.as_bytes(path), status)
#   File "/root/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/errors_impl.py", line 528, in __exit__
#     c_api.TF_GetCode(self.status.status))
# tensorflow.python.framework.errors_impl.PermissionDeniedError: Error executing an HTTP request: HTTP response code 401 with body '{
#  "error": {
#   "errors": [
#    {
#     "domain": "global",
#     "reason": "required",
#     "message": "Anonymous caller does not have storage.objects.get access to es_kiff/model_dir/plugins/beholder/frame.summary.",
#     "locationType": "header",
#     "location": "Authorization"
#    }
#   ],
#   "code": 401,
#   "message": "Anonymous caller does not have storage.objects.get access to es_kiff/model_dir/plugins/beholder/frame.summary."
#  }
# }
# '
# 	 when reading metadata of gs://es_kiff/model_dir/plugins/beholder/frame.summary
# ^C

# %% [markdown]
# Now we can open tensorboard page in [http://localhost:6006](http://localhost:6006)

# %%
# !export GOOGLE_APPLICATION_CREDENTIALS="/u01/notebooks/TFM/Configs/key.json" && python object_detection/export_inference_graph.py \
    --input_type=image_tensor  \
    --pipeline_config_path=gs://$GCS_BUCKET/data/$CONFIG_FILE  \
    --trained_checkpoint_prefix=gs://$GCS_BUCKET/model_dir/model.ckpt-100000  \
    --output_directory=gs://$GCS_BUCKET/outputmodel
# Out:
# 2019-05-12 23:49:05.872138: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.982213 seconds (attempt 1 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-12 23:49:06.950225: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.109334 seconds (attempt 2 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-12 23:49:07.124271: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.8935 seconds (attempt 3 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-12 23:49:08.184455: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.758681 seconds (attempt 4 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-12 23:49:09.098640: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.868269 seconds (attempt 5 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-12 23:49:10.038264: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.398637 seconds (attempt 6 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-12 23:49:10.507263: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 0.802336 seconds (attempt 7 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# 2019-05-12 23:49:11.383057: I tensorflow/core/platform/cloud/retrying_utils.cc:73] The operation failed and will be automatically retried in 1.91901 seconds (attempt 8 out of 10), caused by: Unavailable: Error executing an HTTP request: libcurl code 6 meaning 'Couldn't resolve host name', error details: Couldn't resolve host 'metadata'
# ^C
